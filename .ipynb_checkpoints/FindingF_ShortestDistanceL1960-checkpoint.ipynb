# %%
# !pip install pyDOE
# Out:
# Requirement already satisfied: pyDOE in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyDOE) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyDOE) (1.11.4)

# %%
import jax
import jax.numpy as jnp
from flax import linen as nn
import optax
import copy

from typing import Callable

from functools import partial

import tensorflow as tf
from pyDOE import lhs
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import odeint

import numpy as np


from scipy.optimize import fsolve

# %%
def Lorenz1960(vals, t):

  A_val, F_val, G_val = vals

  A_t = -(1/(k**2) - 1/(k**2 + l**2))*(k * l * F_val * G_val)
  F_t = (1/(l**2) - 1/(k**2 + l**2))*(k * l * A_val * G_val)
  G_t = -(1/2)*(1/(l**2) - 1/(k**2))*(k * l * A_val * F_val)

  vals_t = [A_t, F_t, G_t]

  return vals_t

# %%
t0, tfinal = 0.0, 5.0

# %%
k = 1.0
l = 2.0

# %%
#@jax.jit
def newton(A, G, A_0, F_0, G_0, E) :

  # print("------------------------------------------------------------------------------------------")

  # print("A", A)
  # print("G", G)

  F = ((4*E - (A**2/l**2) - ((2*(G**2))/(k**2 + l**2)))*(k**2))

  # print("F square", F)

  # print("------------------------------------------------------------------------------------------")

  F = jnp.sqrt(F)

  dF_dA = -(A*(k**2))/(F*(l**2))
  dF_dG = -(2*G*(k**2))/(F*(k**2 + l**2))

  D = (A - A_0)**2 + (F - F_0)**2 + (G - G_0)**2

  H1 = 2*(A - A_0) + 2*(F - F_0)*dF_dA
  H2 = 2*(F - F_0)*dF_dG + 2*(G - G_0)

  H = jnp.array([[H1], [H2]])

  dH1_dA = 2 - (2*(k**2))/(l**2) + ((2*(k**2)*F_0)/(l**2))*((F - (A*dF_dA))/(F**2))
  dH1_dG = -((2*(k**2)*F_0*A)/((F**2)*(l**2)))*dF_dG

  dH2_dA = -((4*(k**2)*F_0*G)/((F**2)*(k**2 + l**2)))*dF_dA
  dH2_dG = -((4*(k**2))/(k**2 + l**2)) + ((4*(k**2)*F_0)/(k**2 + l**2))*((F - (G*dF_dG))/(F**2)) + 2

  J = jnp.array([[dH1_dA, dH1_dG], [dH2_dA, dH2_dG]])

  J = jnp.squeeze(J)
  H = jnp.squeeze(H)

  J_inv = jnp.linalg.inv(J)

  # print("WE HERE")

  return J_inv, H

# %%
#@jax.jit
def distance_eq(vals) :

  A_0, F_0, G_0, E_0 = vals

  iter = 0
  err = 1000
  delta = 0.01

  A = A_0 + delta
  F = F_0 + delta
  G = G_0 + delta


  print("------------------------------------------------------------------------------------------")

  print("A", A)

  print("G", G)


  print("------------------------------------------------------------------------------------------")

  x_curr = jnp.array([[A], [G]])

  while (iter < 5) :

    J_inv, H = newton(A, G, A_0, F_0, G_0, E_0)

    mask_J_inv = jnp.isnan(J_inv)
    J_inv = jnp.where(mask_J_inv, 0, J_inv)

    mask_H = jnp.isnan(H)
    H = jnp.where(mask_H, 0, H)

    x_next = x_curr - jnp.matmul(J_inv, H)

    iter = iter + 1

    x_curr = x_next

    A = x_curr[0][0]
    G = x_curr[1][0]

  F = jnp.sqrt(((4*E_0 - (A**2/l**2) - ((2*(G**2))/(k**2 + l**2)))*(k**2)))

  return A, F, G

#@jax.jit
def find_closest(vals) :

  return jax.vmap(distance_eq, 0)(vals)

# %%
class Normalize(nn.Module):
  xmin: float
  xmax: float

  @nn.compact
  def __call__(self, x):
    return 2.0*(x-self.xmin)/(self.xmax - self.xmin) - 1.0

# %%
class HardConstraint(nn.Module):
  t0: float
  tfinal: float
  u0: float

  @nn.compact
  def __call__(self, inputs):
    t, nn = inputs
    return self.u0 + (t-self.t0)/(self.tfinal-self.t0)*nn

# %%
class ClosestPoint(nn.Module):

  E_0: float

  @nn.compact
  def __call__(self, inputs):

    A, F, G = inputs

    A_final, F_final, G_final = find_closest([A, F, G, self.E_0])

    return A_final, F_final, G_final

# %%
class CombineBranches(nn.Module):
  @nn.compact
  def __call__(self, inp1, inp2):
    mult = jnp.sum(inp1*inp2, axis=1)
    out = jnp.reshape(mult, (-1,1))
    return out

# %%
class MLP(nn.Module):

  layers: int
  units: int

  @nn.compact
  def __call__(self, inp):
    b = inp
    for i in range(self.layers-1):
      b = nn.Dense(self.units)(b)
      b = nn.tanh(b)
    out = nn.Dense(4*self.units)(b)
    return out

# %%
def define_collocation_points(t_bdry, N=100):

  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N)

  As = np.random.uniform(0.0, 1.0, size = (N, 1))
  Fs = np.random.uniform(0.0, 1.0, size = (N, 1))
  Gs = np.random.uniform(0.0, 1.0, size = (N, 1))
  Es = (1/4)*((As**2/l**2) + (Fs**2/k**2) + (2*(Gs**2)/(k**2 + l**2)))
  Vs = (1/2)*(As**2 + Fs**2 + 2*(Gs**2))

  sensor_points = np.column_stack((As, Fs, Gs, Es, Vs))

  return (ode_points, sensor_points)

# %%
(de_points, sensors) = define_collocation_points([t0, tfinal], 500)
print(de_points.shape, sensors.shape)
# Out:
# (500, 1) (500, 5)

# %%
class DeepONet(nn.Module):

  t0: float
  tfinal: float
  layers: int
  units: int

  @nn.compact
  def __call__(self, t, u):

    if u.ndim == 1:
      u = jnp.reshape(u, (1,-1))

    A_0 = u[:,:1]
    F_0 = u[:,1:2]
    G_0 = u[:,2:3]
    E_0 = u[:,3:4]
    V_0 = u[:,4:]

    u = u[:,:3]

    t = jnp.reshape(t, (-1,1))

    b = Normalize(self.t0, self.tfinal)(t)

    trunk_net = MLP(self.layers, self.units)(b)
    branch_net = MLP(self.layers, self.units)(u)

    A_tr = trunk_net[:,:self.units]
    F_tr = trunk_net[:,self.units:2*self.units]
    G_tr = trunk_net[:,2*self.units:]
    # E_tr = trunk_net[:,3*self.units:4*self.units]
    # V_tr = trunk_net[:,4*self.units:]

    A_br = branch_net[:,:self.units]
    F_br = branch_net[:,self.units:2*self.units]
    G_br = branch_net[:,2*self.units:]
    # E_br = branch_net[:,3*self.units:4*self.units]
    # V_br = branch_net[:,4*self.units:]

    A = CombineBranches()(A_tr, A_br)
    F = CombineBranches()(F_tr, F_br)
    G = CombineBranches()(G_tr, G_br)

    A = HardConstraint(self.t0, self.tfinal, A_0)([t, A])
    F = HardConstraint(self.t0, self.tfinal, F_0)([t, F])
    G = HardConstraint(self.t0, self.tfinal, G_0)([t, G])

    A = jnp.reshape(A, (-1,))
    F = jnp.reshape(F, (-1,))
    G = jnp.reshape(G, (-1,))

    return A, F, G

# %%
@partial(jax.jit, static_argnums=(2,))
def var_model(t, z, component, params):
  return deeponet.apply(params, t, z)[component][0]

@partial(jax.jit, static_argnums=(2,))
def var(t, z, component, params):
  return jax.vmap(var_model, [0, 0, None, None])(t, z, component, params)

@partial(jax.jit, static_argnums=(2,))
def var_t(t, z, component, params):
  return jax.vmap(jax.grad(var_model, 0), [0, 0, None, None])(t, z, component, params)

@jax.jit
def loss(params, t, z):

  A_t_loss_w = 1.0
  F_t_loss_w = 1.0
  G_t_loss_w = 1.0

  diff_loss_w = 1.0
  E_loss_w = 1.0
  V_loss_w = 1.0

  E_0_val = z[:, -2]
  V_0_val = z[:, -1]

  A_val = var(t, z, 0, params)
  F_val = var(t, z, 1, params)
  G_val = var(t, z, 2, params)

  E_val = (1/4)*((A_val**2/l**2) + (F_val**2/k**2) + (2*(G_val**2)/(k**2 + l**2)))
  E_loss = E_val - E_0_val
  E_loss = jnp.square(E_loss)
  E_loss = jnp.mean(E_loss)


  V_val = (1/2)*(A_val**2 + F_val**2 + 2*(G_val**2))
  V_loss = V_val - V_0_val
  V_loss = jnp.square(V_loss)
  V_loss = jnp.mean(V_loss)


  A_t_val = var_t(t, z, 0, params)
  F_t_val = var_t(t, z, 1, params)
  G_t_val = var_t(t, z, 2, params)

  A_t_loss = A_t_val + (1/(k**2) - 1/(k**2 + l**2))*(k * l * F_val * G_val)
  A_t_loss = jnp.square(A_t_loss)
  A_t_loss = jnp.mean(A_t_loss)


  F_t_loss = F_t_val - (1/(l**2) - 1/(k**2 + l**2))*(k * l * A_val * G_val)
  F_t_loss = jnp.square(F_t_loss)
  F_t_loss = jnp.mean(F_t_loss)

  G_t_loss = G_t_val + (1/2)*(1/(l**2) - 1/(k**2))*(k * l * A_val * F_val)
  G_t_loss = jnp.square(G_t_loss)
  G_t_loss = jnp.mean(G_t_loss)

  diff_loss = A_t_loss_w*A_t_loss + F_t_loss_w*F_t_loss + G_t_loss_w*G_t_loss

  final_loss = diff_loss_w*diff_loss + E_loss_w*E_loss + V_loss_w*V_loss

  return final_loss

@jax.jit
def train_step(params, pdes, z):
  t = pdes[:,0]
  return jax.value_and_grad(loss)(params, t, z)

@partial(jax.jit, static_argnums=(3,))
def optimize(grads, opt_state, params, optimizer_update):
  updates, opt_state = optimizer_update(grads, opt_state, params)
  params = optax.apply_updates(params, updates)
  return params, opt_state

# %%
def train_network(params, des, sensors, epochs=100):

  N = de_points.shape[0]

  nr_batches = 10
  batch_size = len(des)//nr_batches

  print("batch size:", batch_size)

  lr = 1e-3
  optimizer = optax.adam(lr)
  opt_state = optimizer.init(params)

  ds_z = tf.data.Dataset.from_tensor_slices(sensors)
  ds_de = tf.data.Dataset.from_tensor_slices(des)

  ds = tf.data.Dataset.zip((ds_de, ds_z))
  ds = ds.shuffle(N).batch(batch_size)

  epoch_loss = np.zeros(epochs)

  for i in range(epochs):

    for (des_batch, z_batch) in ds:

      loss, grads = train_step(params, des_batch.numpy(), z_batch.numpy())
      params, opt_state = optimize(grads, opt_state, params, optimizer.update)

      epoch_loss[i] += loss

    epoch_loss[i] /= batch_size

    if i % 100  == 0:
      print(f'Loss in epoch {i}: {epoch_loss[i]}')

  return params, epoch_loss

# %%
deeponet = DeepONet(t0, tfinal, layers=4, units=40)

t_init = jnp.full((10, ), 1.0)
u_init = jnp.full((10, 5), 1.0)

params = deeponet.init(jax.random.PRNGKey(0), t_init, u_init)

# %%
epochs = 1000
params, loss = train_network(params, de_points, sensors, epochs)
# Out:
# batch size: 50
# Loss in epoch 0: 0.09596353530883789
# Loss in epoch 100: 0.0020376412570476533
# Loss in epoch 200: 0.0017840427160263062
# Loss in epoch 300: 0.000980892851948738
# Loss in epoch 400: 0.003476537764072418
# Loss in epoch 500: 0.0009961699694395066
# Loss in epoch 600: 0.0005899302661418915
# Loss in epoch 700: 0.0006310446560382843
# Loss in epoch 800: 0.0007693244516849518
# Loss in epoch 900: 0.0004636836424469948

# %%
plt.semilogy(loss)
plt.grid()

# %%
n = 500
t = np.linspace(t0, tfinal, n)

A_data = np.random.uniform(0.0, 1.0, size=(1,))
F_data = np.random.uniform(0.0, 1.0, size=(1,))
G_data = np.random.uniform(0.0, 1.0, size=(1,))
E_data = (1/4)*((A_data**2/l**2) + (F_data**2/k**2) + (2*(G_data**2)/(k**2 + l**2)))
V_data = (1/2)*(A_data**2 + F_data**2 + 2*(G_data**2))

init_data_rk = np.column_stack((A_data, F_data, F_data))
init_data_rk = np.squeeze(init_data_rk)

init_data_model = np.column_stack((A_data, F_data, G_data, E_data, V_data))
init_data_model = np.squeeze(init_data_model)
print(init_data_model.shape)

z = np.repeat(np.expand_dims(init_data_model, axis=0), len(t), axis=0)
print(z.shape)
# Out:
# (5,)
# (500, 5)

# %%
sol_rk = odeint(Lorenz1960, init_data_rk, t)
A_rk, F_rk, G_rk = sol_rk[:,0], sol_rk[:,1], sol_rk[:,2]

# %%
A = jax.vmap(var_model, [0, 0, None, None])(t, z, 0, params)
F = jax.vmap(var_model, [0, 0, None, None])(t, z, 1, params)
G = jax.vmap(var_model, [0, 0, None, None])(t, z, 2, params)

# %%
fig = plt.figure()

plt.subplot(1, 3, 1)
plt.tight_layout()
plt.plot(t, A)
plt.plot(t, A_rk)
plt.xlabel("A")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.subplot(1, 3, 2)
plt.tight_layout()
plt.plot(t, F)
plt.plot(t, F_rk)
plt.xlabel("F")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.subplot(1, 3, 3)
plt.tight_layout()
plt.plot(t, G)
plt.plot(t, G_rk)
plt.xlabel("G")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.show()

# %%
class CDeepONet(nn.Module):

  t0: float
  tfinal: float
  layers: int
  units: int

  @nn.compact
  def __call__(self, t, u):

    if u.ndim == 1:
      u = jnp.reshape(u, (1,-1))

    A_0 = u[:,:1]
    F_0 = u[:,1:2]
    G_0 = u[:,2:3]
    E_0 = u[:,3:4]
    V_0 = u[:,4:]

    u = u[:,:3]

    t = jnp.reshape(t, (-1,1))

    b = Normalize(self.t0, self.tfinal)(t)

    trunk_net = MLP(self.layers, self.units)(b)
    branch_net = MLP(self.layers, self.units)(u)

    A_tr = trunk_net[:,:self.units]
    F_tr = trunk_net[:,self.units:2*self.units]
    G_tr = trunk_net[:,2*self.units:]
    # E_tr = trunk_net[:,3*self.units:4*self.units]
    # V_tr = trunk_net[:,4*self.units:]

    A_br = branch_net[:,:self.units]
    F_br = branch_net[:,self.units:2*self.units]
    G_br = branch_net[:,2*self.units:]
    # E_br = branch_net[:,3*self.units:4*self.units]
    # V_br = branch_net[:,4*self.units:]

    A = CombineBranches()(A_tr, A_br)
    F = CombineBranches()(F_tr, F_br)
    G = CombineBranches()(G_tr, G_br)

    A = HardConstraint(self.t0, self.tfinal, A_0)([t, A])
    F = HardConstraint(self.t0, self.tfinal, F_0)([t, F])
    G = HardConstraint(self.t0, self.tfinal, G_0)([t, G])


    A, F, G = ClosestPoint(E_0)([A, F, G])

    A = jnp.reshape(A, (-1,))
    F = jnp.reshape(F, (-1,))
    G = jnp.reshape(G, (-1,))

    return A, F, G

# %%
#@partial(jax.jit, static_argnums=(2,))
def Cvar_model(t, z, component, params):
  return Cdeeponet.apply(params, t, z)[component][0]

#@partial(jax.jit, static_argnums=(2,))
def Cvar(t, z, component, params):
  return jax.vmap(Cvar_model, [0, 0, None, None])(t, z, component, params)

#@partial(jax.jit, static_argnums=(2,))
def Cvar_t(t, z, component, params):
  return jax.vmap(jax.grad(Cvar_model, 0), [0, 0, None, None])(t, z, component, params)

#@jax.jit
def Closs(params, t, z):

  A_t_loss_w = 1.0
  F_t_loss_w = 1.0
  G_t_loss_w = 1.0

  diff_loss_w = 1.0
  E_loss_w = 0.0
  V_loss_w = 0.0

  E_0_val = z[:, -2]
  V_0_val = z[:, -1]

  A_val = Cvar(t, z, 0, params)
  F_val = Cvar(t, z, 1, params)
  G_val = Cvar(t, z, 2, params)

  E_val = (1/4)*((A_val**2/l**2) + (F_val**2/k**2) + (2*(G_val**2)/(k**2 + l**2)))
  E_loss = E_val - E_0_val
  E_loss = jnp.square(E_loss)
  E_loss = jnp.mean(E_loss)


  V_val = (1/2)*(A_val**2 + F_val**2 + 2*(G_val**2))
  V_loss = V_val - V_0_val
  V_loss = jnp.square(V_loss)
  V_loss = jnp.mean(V_loss)


  A_t_val = Cvar_t(t, z, 0, params)
  F_t_val = Cvar_t(t, z, 1, params)
  G_t_val = Cvar_t(t, z, 2, params)

  A_t_loss = A_t_val + (1/(k**2) - 1/(k**2 + l**2))*(k * l * F_val * G_val)
  A_t_loss = jnp.square(A_t_loss)
  A_t_loss = jnp.mean(A_t_loss)


  F_t_loss = F_t_val - (1/(l**2) - 1/(k**2 + l**2))*(k * l * A_val * G_val)
  F_t_loss = jnp.square(F_t_loss)
  F_t_loss = jnp.mean(F_t_loss)

  G_t_loss = G_t_val + (1/2)*(1/(l**2) - 1/(k**2))*(k * l * A_val * F_val)
  G_t_loss = jnp.square(G_t_loss)
  G_t_loss = jnp.mean(G_t_loss)

  diff_loss = A_t_loss_w*A_t_loss + F_t_loss_w*F_t_loss + G_t_loss_w*G_t_loss

  final_loss = diff_loss_w*diff_loss + E_loss_w*E_loss + V_loss_w*V_loss

  return final_loss

#@jax.jit
def Ctrain_step(params, pdes, z):
  t = pdes[:,0]
  return jax.value_and_grad(Closs)(params, t, z)

#@partial(jax.jit, static_argnums=(3,))
def Coptimize(grads, opt_state, params, optimizer_update):
  updates, opt_state = optimizer_update(grads, opt_state, params)
  params = optax.apply_updates(params, updates)
  return params, opt_state

# %%
def Ctrain_network(params, des, sensors, epochs=100):

  N = de_points.shape[0]

  nr_batches = 10
  batch_size = len(des)//nr_batches

  print("batch size:", batch_size)

  lr = 1e-3
  optimizer = optax.adam(lr)
  opt_state = optimizer.init(params)

  ds_z = tf.data.Dataset.from_tensor_slices(sensors)
  ds_de = tf.data.Dataset.from_tensor_slices(des)

  ds = tf.data.Dataset.zip((ds_de, ds_z))
  ds = ds.shuffle(N).batch(batch_size)

  epoch_loss = np.zeros(epochs)

  for i in range(epochs):

    for (des_batch, z_batch) in ds:

      loss, grads = Ctrain_step(params, des_batch.numpy(), z_batch.numpy())
      params, opt_state = Coptimize(grads, opt_state, params, optimizer.update)

      epoch_loss[i] += loss

    epoch_loss[i] /= batch_size

    if i % 100  == 0:
      print(f'Loss in epoch {i}: {epoch_loss[i]}')

  return params, epoch_loss

# %%
Cdeeponet = CDeepONet(t0, tfinal, layers=4, units=40)

t_init = jnp.full((10, ), 1.0)
u_init = jnp.full((10, 5), 1.0)

Cparams = Cdeeponet.init(jax.random.PRNGKey(0), t_init, u_init)
# Out:
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=1/0)> with
#   val = Array([[0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337],
#        [0.95091337]], dtype=float32)
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=1/0)> with
#   val = Array([[1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351],
#        [1.3798351]], dtype=float32)
#   batch_dim = 0
# ------------------------------------------------------------------------------------------

# %%
Cparams = copy.deepcopy(params)

# %%
epochs = 100
Cparams, Closs = Ctrain_network(Cparams, de_points, sensors, epochs)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59d5043c0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5a85a2160; to 'JaxprTracer' at 0x78c5a85a1940>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c1073c5a0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a82771c0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d6c1710; to 'JaxprTracer' at 0x78c59d6c36a0>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10a03660>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a8276b50>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d6c3b00; to 'JaxprTracer' at 0x78c59d6c3a10>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10a08ec0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a8583ef0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5b02a6200; to 'JaxprTracer' at 0x78c5b02a44a0>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10d08b10>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59d121bb0>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c5b02a7600; to 'JaxprTracer' at 0x78c5b02a5800>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10d06f00>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a8583ee0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d6da700; to 'JaxprTracer' at 0x78c59d6db920>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10d10170>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a8583f40>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c59d6d8f40; to 'JaxprTracer' at 0x78c59d6dbe20>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10d0e5c0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59ce66330>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5a827f5b0; to 'JaxprTracer' at 0x78c5a827f9c0>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c1108d790>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59ce66e50>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c59d52b9c0; to 'JaxprTracer' at 0x78c59d529670>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11072f80>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59ce662d0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5a8452f70; to 'JaxprTracer' at 0x78c5a8450c20>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10d45cf0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59ce66350>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c5a8453060; to 'JaxprTracer' at 0x78c5a8450270>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11138d20>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59cc14880>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59cf54d10; to 'JaxprTracer' at 0x78c59cf57470>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c1167e880>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a835ceb0>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c59cf541d0; to 'JaxprTracer' at 0x78c59cf54a40>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11338910>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59cc148c0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59cdab470; to 'JaxprTracer' at 0x78c59cda9670>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11734b00>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
#       recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59cc14930>, in_tracers=(Traced<ShapedArray(float32[1,1]):JaxprTrace(level=4/0)>,), out_tracer_refs=[<weakref at 0x78c59cda8310; to 'JaxprTracer' at 0x78c59cdab970>], out_avals=[ShapedArray(float32[1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11653840>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59c6898f0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d0483b0; to 'JaxprTracer' at 0x78c59d04b740>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0bf8a935b0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59c689140>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5b0200e50; to 'JaxprTracer' at 0x78c5b0203600>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c0291d770>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a835d680>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5b00fdda0; to 'JaxprTracer' at 0x78c5b00fe160>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11add010>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a835c2a0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5b00fefc0; to 'JaxprTracer' at 0x78c5b00ff1f0>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c118f50e0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a84727b0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d66ee30; to 'JaxprTracer' at 0x78c59d66d940>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c10cdb8e0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# G Traced<ShapedArray(float32[1])>with<BatchTrace(level=4/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#     val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#       primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#       tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#         pval = (ShapedArray(float32[50,1,1]), None)
#         recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c5a8472bd0>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c59d66f3d0; to 'JaxprTracer' at 0x78c59d66e840>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11c03bd0>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#     batch_dim = 0
#   batch_dim = 0
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# A Traced<ShapedArray(float32[1])>with<BatchTrace(level=6/0)> with
#   val = Traced<ShapedArray(float32[1,1])>with<JVPTrace(level=5/0)> with
#     primal = Traced<ShapedArray(float32[1,1])>with<BatchTrace(level=3/0)> with
#       val = Traced<ConcreteArray([[[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]
#
#  [[nan]]], dtype=float32)>with<JVPTrace(level=2/0)> with
#         primal = Array([[[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]],
#
#        [[nan]]], dtype=float32)
#         tangent = Traced<ShapedArray(float32[50,1,1])>with<JaxprTrace(level=1/0)> with
#           pval = (ShapedArray(float32[50,1,1]), None)
#           recipe = JaxprEqnRecipe(eqn_id=<object object at 0x78c59cd10360>, in_tracers=(Traced<ShapedArray(float32[50,1,1]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x78c5a835acf0; to 'JaxprTracer' at 0x78c5a835a700>], out_avals=[ShapedArray(float32[50,1,1])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[50,1,1]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': 'fn', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x5b0c11d28290>, name_stack=NameStack(stack=(Transform(name='jvp'), Transform(name='vmap'), Transform(name='jvp'), Scope(name='CDeepONet'), Scope(name='ClosestPoint_0'), Transform(name='vmap')))))
#       batch_dim = 0
#     tangent = Traced<ShapedArray(float32[1,1])>with<JaxprTrace(level=4/0)> with
#       pval = (ShapedArray(float32[1,1]), None)
# ...
#     715       _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     716     if not has_aux:
# --> 717       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     718     else:
#     719       ans, vjp_py, aux = _vjp(
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/api.py in _vjp(fun, has_aux, *primals)
#    2203   if not has_aux:
#    2204     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2205     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    2206     out_tree = out_tree()
#    2207   else:
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#     130   _, in_tree = tree_flatten(((primals, primals), {}))
#     131   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132   jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     333   def wrapper(*args, **kwargs):
#     334     with TraceAnnotation(name, **decorator_kwargs):
# --> 335       return func(*args, **kwargs)
#     336     return wrapper
#     337   return wrapper
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/partial_eval.py in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772   with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773     fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775     assert not env
#     776     del main, fun, env
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     190
#     191     try:
# --> 192       ans = self.f(*args, **dict(self.params, **kwargs))
#     193     except:
#     194       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-26-60e41929c0b4> in Closs(params, t, z)
#      26
#      27   A_val = Cvar(t, z, 0, params)
# ---> 28   F_val = Cvar(t, z, 1, params)
#      29   G_val = Cvar(t, z, 2, params)
#      30
#
# <ipython-input-26-60e41929c0b4> in Cvar(t, z, component, params)
#       5 #@partial(jax.jit, static_argnums=(2,))
#       6 def Cvar(t, z, component, params):
# ----> 7   return jax.vmap(Cvar_model, [0, 0, None, None])(t, z, component, params)
#       8
#       9 #@partial(jax.jit, static_argnums=(2,))
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1238     axis_size_ = (axis_size if axis_size is not None else
#    1239                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240     out_flat = batching.batch(
#    1241         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     190
#     191     try:
# --> 192       ans = self.f(*args, **dict(self.params, **kwargs))
#     193     except:
#     194       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-26-60e41929c0b4> in Cvar_model(t, z, component, params)
#       1 #@partial(jax.jit, static_argnums=(2,))
#       2 def Cvar_model(t, z, component, params):
# ----> 3   return Cdeeponet.apply(params, t, z)[component][0]
#       4
#       5 #@partial(jax.jit, static_argnums=(2,))
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    2250       method = self.__call__
#    2251     method = _get_unbound_fn(method)
# -> 2252     return apply(
#    2253       method,
#    2254       self,
#
# /usr/local/lib/python3.10/dist-packages/flax/core/scope.py in wrapper(variables, rngs, *args, **kwargs)
#    1099       variables, rngs=rngs, mutable=mutable, flags=flags
#    1100     ).temporary() as root:
# -> 1101       y = fn(root, *args, **kwargs)
#    1102     if mutable is not False:
#    1103       return y, root.mutable_variables()
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in scope_fn(scope, *args, **kwargs)
#    3030     _context.capture_stack.append(capture_intermediates)
#    3031     try:
# -> 3032       return fn(module.clone(parent=scope, _deep_clone=True), *args, **kwargs)
#    3033     finally:
#    3034       _context.capture_stack.pop()
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in wrapped_module_method(*args, **kwargs)
#     699     if args and isinstance(args[0], Module):
#     700       self, args = args[0], args[1:]
# --> 701       return self._call_wrapped_method(fun, args, kwargs)
#     702     else:
#     703       return fun(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in _call_wrapped_method(self, fun, args, kwargs)
#    1231       if _use_named_call:
#    1232         with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1233           y = run_fun(self, *args, **kwargs)
#    1234       else:
#    1235         y = run_fun(self, *args, **kwargs)
#
# <ipython-input-25-316d5a8054cf> in __call__(self, t, u)
#      48
#      49
# ---> 50     A, F, G = ClosestPoint(E_0)([A, F, G])
#      51
#      52     A = jnp.reshape(A, (-1,))
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in wrapped_module_method(*args, **kwargs)
#     699     if args and isinstance(args[0], Module):
#     700       self, args = args[0], args[1:]
# --> 701       return self._call_wrapped_method(fun, args, kwargs)
#     702     else:
#     703       return fun(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/flax/linen/module.py in _call_wrapped_method(self, fun, args, kwargs)
#    1231       if _use_named_call:
#    1232         with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1233           y = run_fun(self, *args, **kwargs)
#    1234       else:
#    1235         y = run_fun(self, *args, **kwargs)
#
# <ipython-input-10-8eb7f39fed9c> in __call__(self, inputs)
#       8     A, F, G = inputs
#       9
# ---> 10     A_final, F_final, G_final = find_closest([A, F, G, self.E_0])
#      11
#      12     return A_final, F_final, G_final
#
# <ipython-input-7-5025a5769cf4> in find_closest(vals)
#      50 def find_closest(vals) :
#      51
# ---> 52   return jax.vmap(distance_eq, 0)(vals)
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1238     axis_size_ = (axis_size if axis_size is not None else
#    1239                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240     out_flat = batching.batch(
#    1241         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     190
#     191     try:
# --> 192       ans = self.f(*args, **dict(self.params, **kwargs))
#     193     except:
#     194       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-7-5025a5769cf4> in distance_eq(vals)
#      26   while (iter < 5) :
#      27
# ---> 28     J_inv, H = newton(A, G, A_0, F_0, G_0, E_0)
#      29
#      30     mask_J_inv = jnp.isnan(J_inv)
#
# <ipython-input-29-c414fca3b016> in newton(A, G, A_0, F_0, G_0, E)
#      21
#      22   H1 = 2*(A - A_0) + 2*(F - F_0)*dF_dA
# ---> 23   H2 = 2*(F - F_0)*dF_dG + 2*(G - G_0)
#      24
#      25   H = jnp.array([[H1], [H2]])
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/numpy/array_methods.py in op(self, *args)
#     734 def _forward_operator_to_aval(name):
#     735   def op(self, *args):
# --> 736     return getattr(self.aval, f"_{name}")(self, *args)
#     737   return op
#     738
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     262     args = (other, self) if swap else (self, other)
#     263     if isinstance(other, _accepted_binop_types):
# --> 264       return binary_op(*args)
#     265     # Note: don't use isinstance here, because we don't want to raise for
#     266     # subclasses, e.g. NamedTuple objects that may override operators.
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     296   @api_boundary
#     297   def cache_miss(*args, **kwargs):
# --> 298     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     299         jit_info, *args, **kwargs)
#     300     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _python_pjit_helper(jit_info, *args, **kwargs)
#     174
#     175   try:
# --> 176     out_flat = pjit_p.bind(*args_flat, **params)
#     177   except pxla.DeviceAssignmentMismatchError as e:
#     178     fails, = e.args
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2786     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787                  else axis_main.with_cur_sublevel())
# -> 2788     return self.bind_with_trace(top_trace, args, params)
#    2789
#    2790
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     423
#     424   def bind_with_trace(self, trace, args, params):
# --> 425     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     427
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     431       frame = self.get_frame(vals_in, dims_in)
#     432       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434     src = source_info_util.current()
#     435     if primitive.multiple_results:
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1706       if axis_out is not None else o
#    1707       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1708   vals_out = pjit_p.bind(
#    1709     *vals_in,
#    1710     jaxpr=new_jaxpr,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2786     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787                  else axis_main.with_cur_sublevel())
# -> 2788     return self.bind_with_trace(top_trace, args, params)
#    2789
#    2790
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     423
#     424   def bind_with_trace(self, trace, args, params):
# --> 425     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     427
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     431       frame = self.get_frame(vals_in, dims_in)
#     432       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434     src = source_info_util.current()
#     435     if primitive.multiple_results:
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1706       if axis_out is not None else o
#    1707       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1708   vals_out = pjit_p.bind(
#    1709     *vals_in,
#    1710     jaxpr=new_jaxpr,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2786     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787                  else axis_main.with_cur_sublevel())
# -> 2788     return self.bind_with_trace(top_trace, args, params)
#    2789
#    2790
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     423
#     424   def bind_with_trace(self, trace, args, params):
# --> 425     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     427
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/ad.py in process_primitive(self, primitive, tracers, params)
#     312       msg = f"Differentiation rule for '{primitive}' not implemented"
#     313       raise NotImplementedError(msg)
# --> 314     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     315     if primitive.multiple_results:
#     316       return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1771   _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1772   _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1773   outputs = pjit_p.bind(
#    1774       *primals_in, *_filter_zeros_in(tangents_in),
#    1775       jaxpr=jaxpr_jvp,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2786     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787                  else axis_main.with_cur_sublevel())
# -> 2788     return self.bind_with_trace(top_trace, args, params)
#    2789
#    2790
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     423
#     424   def bind_with_trace(self, trace, args, params):
# --> 425     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     427
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#     210   def process_primitive(self, primitive, tracers, params):
#     211     if primitive in custom_partial_eval_rules:
# --> 212       return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     213     else:
#     214       return self.default_process_primitive(primitive, tracers, params)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    1837
#    1838   # Output-to-output forwarding: compute which residuals are just primal outputs
# -> 1839   out_vars, res_vars = split_list(known_jaxpr.jaxpr.outvars, [num_out_primals])
#    1840   idx_map = {id(v): i for i, v in enumerate(out_vars)}
#    1841   out_fwd = [None] * num_out_primals + [idx_map.get(id(v)) for v in res_vars]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/util.py in split_list(args, ns)
#     127   lists = []
#     128   for n in ns:
# --> 129     lists.append(args[:n])
#     130     args = args[n:]
#     131   lists.append(args)
#
# KeyboardInterrupt:

# %%
plt.semilogy(Closs)
plt.grid()

# %%
A = jax.vmap(Cvar_model, [0, 0, None, None])(t, z, 0, Cparams)
F = jax.vmap(Cvar_model, [0, 0, None, None])(t, z, 1, Cparams)
G = jax.vmap(Cvar_model, [0, 0, None, None])(t, z, 2, Cparams)

# %%
print(A)

# %%
fig = plt.figure()

plt.subplot(1, 3, 1)
plt.tight_layout()
plt.plot(t, A)
plt.plot(t, A_rk)
plt.xlabel("A")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.subplot(1, 3, 2)
plt.tight_layout()
plt.plot(t, F)
plt.plot(t, F_rk)
plt.xlabel("F")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.subplot(1, 3, 3)
plt.tight_layout()
plt.plot(t, G)
plt.plot(t, G_rk)
plt.xlabel("G")
plt.grid()
plt.legend(['DeepONet','RK45'])

plt.show()
